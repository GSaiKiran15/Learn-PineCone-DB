# %% [markdown]
# [![Open In Colab](https://colab.research.google.com/assets/colab-badge.svg)](https://colab.research.google.com/github/pinecone-io/examples/blob/master/docs/quick-tour/hello-pinecone.ipynb) [![Open nbviewer](https://raw.githubusercontent.com/pinecone-io/examples/master/assets/nbviewer-shield.svg)](https://nbviewer.org/github/pinecone-io/examples/blob/master/docs/quick-tour/hello-pinecone.ipynb)

# %% [markdown]
# # Hello, Pinecone!
#
# This notebook will walk through the steps to get a simple Pinecone index up and running.

# %% [markdown]
# ## Prerequisites

# %% [markdown]
# First we need to install a few dependencies

# %%
# !pip install -qU pandas==2.2.3 pinecone==6.0.2

# %% [markdown]
# ## Getting started
#
# We begin by instantiating an instance of the Pinecone client. To do this we need a [free API key](https://app.pinecone.io).

# %%
import os
from pinecone import Pinecone
from dotenv import  load_dotenv

# Get your API key at app.pinecone.io
load_dotenv()
api_key = os.environ.get("PINECONE_API_KEY") or "PINECONE_API_KEY"

# Instantiate the Pinecone client
if not api_key:
    print("API Key not found")
else:
    print(api_key)
pc = Pinecone(api_key=api_key)
# Out:
# pcsk_46KApR_Qvk7fdov2AJ2syRt3iUPGBwPk49NzE8qz5xFSN779V4rPZ8EXq8xLnuB4yyMmv5

# %% [markdown]
# # Pinecone quickstart
#
# With Pinecone you can create a vector index where you can easily store and search through your vector embeddings.

# %%
# Giving our index a name
index_name = "hello-pinecone"

# %%
# Delete the index if an index of the same name already exists
if pc.has_index(name=index_name):
    pc.delete_index(name=index_name)
# Out:
# ---------------------------------------------------------------------------
# UnauthorizedException                     Traceback (most recent call last)
# Cell In[13], line 2
#       1 # Delete the index if an index of the same name already exists
# ----> 2 if pc.has_index(name=index_name):
#       3     pc.delete_index(name=index_name)
#
# File ~\AppData\Roaming\Python\Python313\site-packages\pinecone\control\pinecone.py:247, in Pinecone.has_index(self, name)
#     246 def has_index(self, name: str) -> bool:
# --> 247     if name in self.list_indexes().names():
#     248         return True
#     249     else:
#
# File ~\AppData\Roaming\Python\Python313\site-packages\pinecone\control\pinecone.py:235, in Pinecone.list_indexes(self)
#     234 def list_indexes(self) -> IndexList:
# --> 235     response = self.index_api.list_indexes()
#     236     return IndexList(response)
#
# File ~\AppData\Roaming\Python\Python313\site-packages\pinecone\openapi_support\endpoint.py:102, in Endpoint.__call__(self, *args, **kwargs)
#      91 def __call__(self, *args, **kwargs):
#      92     """This method is invoked when endpoints are called
#      93     Example:
#      94
#    (...)    100
#     101     """
# --> 102     return self.callable(self, *args, **kwargs)
#
# File ~\AppData\Roaming\Python\Python313\site-packages\pinecone\core\openapi\db_control\api\manage_indexes_api.py:708, in ManageIndexesApi.__init__.<locals>.__list_indexes(self, **kwargs)
#     674 """List indexes  # noqa: E501
#     675
#     676 This operation returns a list of all indexes in a project.  # noqa: E501
#    (...)    705         thread.
#     706 """
#     707 kwargs = self._process_openapi_kwargs(kwargs)
# --> 708 return self.call_with_http_info(**kwargs)
#
# File ~\AppData\Roaming\Python\Python313\site-packages\pinecone\openapi_support\endpoint.py:134, in Endpoint.call_with_http_info(self, **kwargs)
#     124 params = EndpointUtils.gather_params(
#     125     attribute_map=self.attribute_map,
#     126     location_map=self.location_map,
#    (...)    129     kwargs=kwargs,
#     130 )
#     132 HeaderUtil.prepare_headers(headers_map=self.headers_map, params=params)
# --> 134 return self.api_client.call_api(
#     135     self.settings["endpoint_path"],
#     136     self.settings["http_method"],
#     137     path_params=params["path"],
#     138     query_params=params["query"],
#     139     header_params=params["header"],
#     140     body=params["body"],
#     141     post_params=params["form"],
#     142     files=params["file"],
#     143     response_type=self.settings["response_type"],
#     144     auth_settings=self.settings["auth"],
#     145     async_req=kwargs["async_req"],
#     146     async_threadpool_executor=kwargs.get("async_threadpool_executor", None),
#     147     _check_type=kwargs["_check_return_type"],
#     148     _return_http_data_only=kwargs["_return_http_data_only"],
#     149     _preload_content=kwargs["_preload_content"],
#     150     _request_timeout=kwargs["_request_timeout"],
#     151     _host=_host,
#     152     collection_formats=params["collection_format"],
#     153 )
#
# File ~\AppData\Roaming\Python\Python313\site-packages\pinecone\openapi_support\api_client.py:300, in ApiClient.call_api(self, resource_path, method, path_params, query_params, header_params, body, post_params, files, response_type, auth_settings, async_req, async_threadpool_executor, _return_http_data_only, collection_formats, _preload_content, _request_timeout, _host, _check_type)
#     279     return self.threadpool_executor.submit(
#     280         self.__call_api,
#     281         resource_path,
#    (...)    296         _check_type,
#     297     )
#     299 if not async_req:
# --> 300     return self.__call_api(
#     301         resource_path,
#     302         method,
#     303         path_params,
#     304         query_params,
#     305         header_params,
#     306         body,
#     307         post_params,
#     308         files,
#     309         response_type,
#     310         auth_settings,
#     311         _return_http_data_only,
#     312         collection_formats,
#     313         _preload_content,
#     314         _request_timeout,
#     315         _host,
#     316         _check_type,
#     317     )
#     319 return self.pool.apply_async(
#     320     self.__call_api,
#     321     (
#    (...)    338     ),
#     339 )
#
# File ~\AppData\Roaming\Python\Python313\site-packages\pinecone\openapi_support\api_client.py:178, in ApiClient.__call_api(self, resource_path, method, path_params, query_params, header_params, body, post_params, files, response_type, auth_settings, _return_http_data_only, collection_formats, _preload_content, _request_timeout, _host, _check_type)
#     176 except PineconeApiException as e:
#     177     e.body = e.body.decode("utf-8")
# --> 178     raise e
#     180 self.last_response = response_data
#     182 return_data = response_data
#
# File ~\AppData\Roaming\Python\Python313\site-packages\pinecone\openapi_support\api_client.py:166, in ApiClient.__call_api(self, resource_path, method, path_params, query_params, header_params, body, post_params, files, response_type, auth_settings, _return_http_data_only, collection_formats, _preload_content, _request_timeout, _host, _check_type)
#     157 url = build_request_url(
#     158     config=config,
#     159     processed_path_params=path_params_tuple,
#     160     resource_path=resource_path,
#     161     _host=_host,
#     162 )
#     164 try:
#     165     # perform request and return response
# --> 166     response_data = self.request(
#     167         method,
#     168         url,
#     169         query_params=processed_query_params,
#     170         headers=headers_tuple,
#     171         post_params=processed_post_params,
#     172         body=body,
#     173         _preload_content=_preload_content,
#     174         _request_timeout=_request_timeout,
#     175     )
#     176 except PineconeApiException as e:
#     177     e.body = e.body.decode("utf-8")
#
# File ~\AppData\Roaming\Python\Python313\site-packages\pinecone\openapi_support\api_client.py:354, in ApiClient.request(self, method, url, query_params, headers, post_params, body, _preload_content, _request_timeout)
#     352 """Makes the HTTP request using RESTClient."""
#     353 if method == "GET":
# --> 354     return self.rest_client.GET(
#     355         url,
#     356         query_params=query_params,
#     357         _preload_content=_preload_content,
#     358         _request_timeout=_request_timeout,
#     359         headers=headers,
#     360     )
#     361 elif method == "HEAD":
#     362     return self.rest_client.HEAD(
#     363         url,
#     364         query_params=query_params,
#    (...)    367         headers=headers,
#     368     )
#
# File ~\AppData\Roaming\Python\Python313\site-packages\pinecone\openapi_support\rest_utils.py:75, in RestClientInterface.GET(self, url, headers, query_params, _preload_content, _request_timeout)
#      72 def GET(
#      73     self, url, headers=None, query_params=None, _preload_content=True, _request_timeout=None
#      74 ):
# ---> 75     return self.request(
#      76         "GET",
#      77         url,
#      78         headers=headers,
#      79         _preload_content=_preload_content,
#      80         _request_timeout=_request_timeout,
#      81         query_params=query_params,
#      82     )
#
# File ~\AppData\Roaming\Python\Python313\site-packages\pinecone\openapi_support\rest_urllib3.py:260, in Urllib3RestClient.request(self, method, url, query_params, headers, body, post_params, _preload_content, _request_timeout)
#     257     # log response body
#     258     logger.debug("response body: %s", r.data)
# --> 260 return raise_exceptions_or_return(r)
#
# File ~\AppData\Roaming\Python\Python313\site-packages\pinecone\openapi_support\rest_utils.py:38, in raise_exceptions_or_return(r)
#      36 if not 200 <= r.status <= 299:
#      37     if r.status == 401:
# ---> 38         raise UnauthorizedException(http_resp=r)
#      40     if r.status == 403:
#      41         raise ForbiddenException(http_resp=r)
#
# UnauthorizedException: (401)
# Reason: Unauthorized
# HTTP response headers: HTTPHeaderDict({'x-pinecone-api-version': '2025-01', 'x-cloud-trace-context': 'c931600a10beb04cfa0cdd7d56c9ddfe', 'date': 'Fri, 16 Jan 2026 21:28:04 GMT', 'content-type': 'text/html', 'server': 'Google Frontend', 'Content-Length': '15', 'Via': '1.1 google', 'Alt-Svc': 'h3=":443"; ma=2592000,h3-29=":443"; ma=2592000'})
# HTTP response body: Invalid API Key

# %% [markdown]
# ### Creating a Pinecone Index
#
# When creating the index we need to define several configuration properties.
#
# - `name` can be anything we like. The name is used as an identifier for the index when performing other operations such as `describe_index`, `delete_index`, and so on.
# - `metric` specifies the similarity metric that will be used later when you make queries to the index.
# - `dimension` should correspond to the dimension of the dense vectors produced by your embedding model. In this quick start, we are using made-up data so a small value is simplest.
# - `spec` holds a specification which tells Pinecone how you would like to deploy our index. You can find a list of all [available providers and regions here](https://docs.pinecone.io/troubleshooting/available-cloud-regions).
#
# There are more configurations available, but this minimal set will get us started.

# %%
from pinecone import ServerlessSpec, CloudProvider, AwsRegion, Metric

pc.create_index(
    name=index_name,
    metric=Metric.COSINE,
    dimension=3,
    spec=ServerlessSpec(cloud=CloudProvider.AWS, region=AwsRegion.US_EAST_1),
)
# Out:
# {
#     "name": "hello-pinecone",
#     "metric": "cosine",
#     "host": "hello-pinecone-04dftrb.svc.aped-4627-b74a.pinecone.io",
#     "spec": {
#         "serverless": {
#             "cloud": "aws",
#             "region": "us-east-1"
#         }
#     },
#     "status": {
#         "ready": true,
#         "state": "Ready"
#     },
#     "vector_type": "dense",
#     "dimension": 3,
#     "deletion_protection": "disabled",
#     "tags": null
# }

# %% [markdown]
# We can look up the configuration for the index anytime we like by using `describe_index`

# %%
description = pc.describe_index(name=index_name)
description
# Out:
# {
#     "name": "hello-pinecone",
#     "metric": "cosine",
#     "host": "hello-pinecone-04dftrb.svc.aped-4627-b74a.pinecone.io",
#     "spec": {
#         "serverless": {
#             "cloud": "aws",
#             "region": "us-east-1"
#         }
#     },
#     "status": {
#         "ready": true,
#         "state": "Ready"
#     },
#     "vector_type": "dense",
#     "dimension": 3,
#     "deletion_protection": "disabled",
#     "tags": null
# }

# %% [markdown]
# ## Upserting data into the index
#
# We can see the index ready. Now we will create some simple vectors that will serve as our examples.

# %%
# Instantiate an Index client
index = pc.Index(host=description.host)

# %%
import random
import pandas as pd


def create_simulated_data_in_df(num_vectors):
    df = pd.DataFrame(
        data={
            "id": [f"id-{i}" for i in range(num_vectors)],
            "vector": [
                [random.random() for i in range(description.dimension)]
                for _ in range(num_vectors)
            ],
        }
    )
    return df


df = create_simulated_data_in_df(10)

df.head()
# Out:
#      id                                             vector
# 0  id-0  [0.3474750786605746, 0.6812122134203057, 0.254...
# 1  id-1  [0.47161648128045763, 0.525194337223996, 0.874...
# 2  id-2  [0.7632071242082747, 0.586994578134045, 0.9707...
# 3  id-3  [0.4555119063670492, 0.050099943021998605, 0.8...
# 4  id-4  [0.5413116896861098, 0.7502453690384088, 0.310...

# %% [markdown]
# We perform `upsert` operations in our index. This call will insert a new vector in the index or update the vector if the id was already present.

# %%
index.upsert(vectors=zip(df.id, df.vector))  # insert vectors
# Out:
# {'upserted_count': 10}

# %%
import time


def is_fresh(index):
    stats = index.describe_index_stats()
    vector_count = stats.total_vector_count
    print(f"Vector count: ", vector_count)
    return vector_count > 0


while not is_fresh(index):
    # It takes a few moments for vectors we just upserted
    # to become available for querying
    time.sleep(5)
# Out:
# Vector count:  10

# %%
# View index stats
index.describe_index_stats()
# Out:
# {'dimension': 3,
#  'index_fullness': 0.0,
#  'metric': 'cosine',
#  'namespaces': {'': {'vector_count': 10}},
#  'total_vector_count': 10,
#  'vector_type': 'dense'}

# %% [markdown]
# ## Running a query
#
# Next we can run a query.
#
# In a more realistic scenario, the `vector` values passing into `query` would be an embedding vector of something meaningful. But for this simple walkthrough we will use made up values. The query will succeed as long as the dimension matches the dimension of our index.
#
# `top_k` specifies the number of results we would like returned. The method will return up to `top_k` results, but may be less if there are fewer than `top_k` vectors in your index or if all indexes have been filtered out using metadata filters.

# %%
# In a more realistic scenario, this would be an embedding vector
# that encodes something meaningful. For this simple demo, we will
# make up a vector that matches the dimension of our index.
query_embedding = [2.0, 2.0, 2.0]

index.query(vector=query_embedding, top_k=5, include_values=True)
# Out:
# {'matches': [{'id': 'id-1',
#               'score': 0.997445405,
#               'values': [0.827472806, 0.835075, 0.961279154]},
#              {'id': 'id-3',
#               'score': 0.972650886,
#               'values': [0.587944388, 0.559045732, 0.924576044]},
#              {'id': 'id-9',
#               'score': 0.958372176,
#               'values': [0.323696256, 0.569944143, 0.704567373]},
#              {'id': 'id-4',
#               'score': 0.921065927,
#               'values': [0.610429883, 0.266597837, 0.858841419]},
#              {'id': 'id-7',
#               'score': 0.906878114,
#               'values': [0.2434071, 0.738737464, 0.967846]}],
#  'namespace': '',
#  'usage': {'read_units': 1}}

# %% [markdown]
# ## Delete the Index
# Delete the index once you are sure that you do not want to use it anymore. **Deletion is permanent**. Once the index is deleted, you cannot use it again.

# %%
pc.delete_index(name=index_name)
